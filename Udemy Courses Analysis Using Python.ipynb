# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the datasets

# %%
data=pd.read_csv("udemy_Courses.csv",parse_dates=['published_timestamp'])

# %% [markdown]
# # Exploratory data Analysis and data cleaning

# %%
#checking datatypes
data.dtypes
# Out:
# course_id                            int64
# course_title                        object
# url                                 object
# is_paid                               bool
# price                                int64
# num_subscribers                      int64
# num_reviews                          int64
# num_lectures                         int64
# level                               object
# content_duration                   float64
# published_timestamp    datetime64[ns, UTC]
# subject                             object
# dtype: object

# %%
data.head(10)
# Out:
#    course_id                                       course_title  \
# 0    1070968                 Ultimate Investment Banking Course
# 1    1113822  Complete GST Course & Certification - Grow You...
# 2    1006314  Financial Modeling for Business Analysts and C...
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...
# 4    1011058       How To Maximize Your Profits Trading Options
# 5     192870  Trading Penny Stocks: A Guide for All Levels I...
# 6     739964  Investing And Trading For Beginners: Mastering...
# 7     403100  Trading Stock Chart Patterns For Immediate, Ex...
# 8     476268  Options Trading 3 : Advanced Stock Profit and ...
# 9    1167710  The Only Investment Strategy You Need For Your...
#
#                                                  url  is_paid  price  \
# 0  https://www.udemy.com/ultimate-investment-bank...     True    200
# 1      https://www.udemy.com/goods-and-services-tax/     True     75
# ...

# %%
data.tail(10)
# Out:
#       course_id                                       course_title  \
# 3668     270976                             A how to guide in HTML
# 3669     679992                  Building Better APIs with GraphQL
# 3670     330900  Learn Grunt with Examples: Automate Your Front...
# 3671     667122  Build A Stock Downloader With Visual Studio 20...
# 3672     865438    jQuery UI in Action: Build 5 jQuery UI Projects
# 3673     775618  Learn jQuery from Scratch - Master of JavaScri...
# 3674    1088178  How To Design A WordPress Website With No Codi...
# 3675     635248                      Learn and Build using Polymer
# 3676     905096  CSS Animations: Create Amazing Effects on Your...
# 3677     297602  Using MODX CMS to Build Websites: A Beginner's...
#
#                                                     url  is_paid  price  \
# 3668      https://www.udemy.com/a-how-to-guide-in-html/    False      0
# 3669  https://www.udemy.com/building-better-apis-wit...     True     50
# ...

# %%
data.shape
# Out:
# (3678, 12)

# %%
print("Number of Rows:-",data.shape[0])
print("Number of Columns:-",data.shape[1])
# Out:
# Number of Rows:- 3678
# Number of Columns:- 12

# %% [markdown]
# # TASKS

# %% [markdown]
# # 1.Getting Information About Our dataset like total number of rows and columns,datatypes of each column and Memory requirements

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3678 entries, 0 to 3677
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   course_id            3678 non-null   int64
#  1   course_title         3678 non-null   object
#  2   url                  3678 non-null   object
#  3   is_paid              3678 non-null   bool
#  4   price                3678 non-null   int64
#  5   num_subscribers      3678 non-null   int64
#  6   num_reviews          3678 non-null   int64
#  7   num_lectures         3678 non-null   int64
#  8   level                3678 non-null   object
#  9   content_duration     3678 non-null   float64
#  10  published_timestamp  3678 non-null   datetime64[ns, UTC]
#  11  subject              3678 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), float64(1), int64(5), object(4)
# memory usage: 319.8+ KB

# %% [markdown]
# # 2:Checking Missing values For All Columns If Any Then Replace them and visualize on Heatmap

# %%
print("Any Missing Value?",data.isnull().values.any())
# Out:
# Any Missing Value? False

# %%
data.isnull().sum()
# Out:
# course_id              0
# course_title           0
# url                    0
# is_paid                0
# price                  0
# num_subscribers        0
# num_reviews            0
# num_lectures           0
# level                  0
# content_duration       0
# published_timestamp    0
# subject                0
# dtype: int64

# %%
sns.heatmap(data.isnull())
plt.title("checking Missing values")
plt.show()

# %% [markdown]
# # 3:Checking Duplicates If FindThen Drop Records

# %%
dup=data.duplicated().any()
print("Are There Any Duplicated Value in Data?",dup)
# Out:
# Are There Any Duplicated Value in Data? True

# %%
data=data.drop_duplicates()

# %%
dup=data.duplicated().any()
print("Are There Any Duplicated Value in Data?",dup)
# Out:
# Are There Any Duplicated Value in Data? False

# %% [markdown]
# # 4. Dropping the columns which are no use in datasets.

# %%
data.drop('url',axis=1,inplace=True)

# %%
data.head(5)
# Out:
#    course_id                                       course_title  is_paid  \
# 0    1070968                 Ultimate Investment Banking Course     True
# 1    1113822  Complete GST Course & Certification - Grow You...     True
# 2    1006314  Financial Modeling for Business Analysts and C...     True
# 3    1210588  Beginner to Pro - Financial Analysis in Excel ...     True
# 4    1011058       How To Maximize Your Profits Trading Options     True
#
#    price  num_subscribers  num_reviews  num_lectures               level  \
# 0    200             2147           23            51          All Levels
# 1     75             2792          923           274          All Levels
# 2     45             2174           74            51  Intermediate Level
# 3     95             2451           11            36          All Levels
# 4    200             1276           45            26  Intermediate Level
#
#    content_duration       published_timestamp           subject
# ...

# %% [markdown]
# # Data Analysis to Answer Business Question

# %% [markdown]
# # 1. Find out Number Of Courses Per Subject and Make Suitable Plot

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['subject'].value_counts()
# Out:
# Web Development        1199
# Business Finance       1191
# Musical Instruments     680
# Graphic Design          602
# Name: subject, dtype: int64

# %%
sns.countplot(data['subject'])
plt.xlabel("Subjects",fontsize=18)
plt.ylabel("Number of Courses Per Subject",fontsize=15)
plt.xticks(rotation=70)
plt.title("Courses Per Subject")
plt.show()

# %% [markdown]
# # 2.For Which Levels ,Udemy Courses Providing The Courses and Visulaize Them

# %%
data['level'].value_counts()
# Out:
# All Levels            1925
# Beginner Level        1268
# Intermediate Level     421
# Expert Level            58
# Name: level, dtype: int64

# %%
sns.countplot(data['level'])
plt.xlabel("Levels",fontsize=18)
plt.ylabel("Number of Courses Per Level",fontsize=15)
plt.xticks(rotation=70)
plt.title("Level Wise Plot")
plt.show()

# %% [markdown]
# # 3. Display The Count Of Paid and Free Courses

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
data['is_paid'].value_counts()
# Out:
# True     3362
# False     310
# Name: is_paid, dtype: int64

# %%
plt.figure(figsize=(3,4))
sns.countplot(data['is_paid'])
plt.xlabel("Levels",fontsize=18)
plt.ylabel("Number of Free and Paid Courses",fontsize=15)
plt.show()

# %% [markdown]
# # 4. Find a Relation Between Reviews and Lectures

# %%
data.groupby(['is_paid']).mean()
# Out:
#              course_id      price  num_subscribers  num_reviews  num_lectures  \
# is_paid
# False    691446.970968   0.000000     11533.951613   425.929032     21.416129
# True     674463.946163  72.198096      2421.270077   131.516359     41.866746
#
#          content_duration
# is_paid
# False            2.210753
# True             4.271584

# %% [raw]
# **As we can Analysis using Above Table That People who paid for the Courses see more Number Of Lectures and Their duration time is More then the persons Who take free subscriptions.It means we have to sold the courses at some price so that people can see them with more enthatusim rather just to take subscriptions.

# %% [markdown]
# # 5.On Udemy Which Have a higher Number Of Subscribers Free or Paid?

# %%
data.groupby(['is_paid'])["num_subscribers"].mean()
# Out:
# is_paid
# False    11533.951613
# True      2421.270077
# Name: num_subscribers, dtype: float64

# %%
plt.figure(figsize=(3,4))
sns.barplot(x="is_paid",y="num_subscribers",data=data)
plt.xlabel("Paid courses",fontsize=15)
plt.ylabel("Number Of Subsribers",fontsize=15)
plt.title("Subscribers Based On Paid Courses")
plt.show()

# %% [markdown]
# # 6. Which Level has The Highest Number Of Subscribers ? Also Plot them On barchart

# %%
data.groupby(['level'])["num_subscribers"].mean()
# Out:
# level
# All Levels            3569.761558
# Beginner Level        3195.459779
# Expert Level           865.448276
# Intermediate Level    1762.482185
# Name: num_subscribers, dtype: float64

# %%
sns.barplot(x="level",y="num_subscribers",data=data)
plt.xlabel("Levels",fontsize=15)
plt.ylabel("Number Of Subsribers",fontsize=15)
plt.xticks(rotation=60)
plt.title("Subscribers Based On Levels")
plt.show()

# %% [raw]
# **:-As we can see that in Barplot that Begineer Level has more subscribers so We have to Design More content or Courses that Give basic Understaning of the languages.

# %% [markdown]
# # 7. Display 10 Most Popular Courses As Per Number Of Subscribers On Udemy and Also Plot them Using Seabrorn

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
top_10=data.sort_values(by="num_subscribers",ascending=False).head(10)
top_10
# Out:
#       course_id                                       course_title  is_paid  \
# 2827      41295               Learn HTML5 Programming From Scratch    False
# 3032      59014                     Coding for Entrepreneurs Basic    False
# 3230     625204                         The Web Developer Bootcamp     True
# 2783     173548  Build Your First Website in 1 Week with HTML5 ...    False
# 3232     764164              The Complete Web Developer Course 2.0     True
# 1896      19421              Free Beginner Electric Guitar Lessons    False
# 2589     473160  Web Design for Web Developers: Build Beautiful...    False
# 2619      94430             Learn Javascript & JQuery From Scratch     True
# 3289     130064  Practical PHP: Master the Basics and Code Dyna...    False
# 3247     364426          JavaScript: Understanding the Weird Parts     True
#
#       price  num_subscribers  num_reviews  num_lectures           level  \
# ...

# %%
sns.barplot(x="num_subscribers",y="course_title",data=top_10)
plt.xlabel("Number of Subscriber",fontsize=15)
plt.ylabel("Course Title",fontsize=15)
plt.title("Top 10 Courses based On Subscribers")
plt.show()

# %% [markdown]
# # 8. Find The Courses which Is Having The Highest Number Of Reviews. and Also Visualize them.

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(10,4))
sns.barplot(x="subject",y="num_reviews",data=data)
plt.xlabel("subject",fontsize=15)
plt.ylabel("Number of Reviews",fontsize=15)
plt.title("Reviews Based On Subjects")
plt.show()

# %% [markdown]
# # 9. Does Price Affect Number Of Reviews?

# %% [markdown]
# # a.Make a ScatterPlot to Understand the Effect Of price on reviews

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
plt.figure(figsize=(15,7))
sns.scatterplot(x="price",y="num_reviews",data=data)
plt.xlabel("Price",fontsize=15)
plt.ylabel("Number of Reviews",fontsize=15)
plt.title("Connection between Reviews and Prices")
plt.show()

# %% [markdown]
# # b. Do You See Any Patterns?

# %% [raw]
# **Yes, from the given plot, we can say that there is correlation between Price and Reviews.

# %% [markdown]
# # c. How Do You Explain The Pattern?

# %% [raw]
# **From the given plot, we can see that, on increase in the Price, the size also increases and there is positive correlation between Price and Reviews.

# %% [markdown]
# # 10.Find Total Numbers Of Courses related to Python

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject'],
#       dtype='object')

# %%
data[data['course_title'].str.contains('python', case=False)]
# Out:
#       course_id                                       course_title  is_paid  \
# 14      1196544   Python Algo Trading: Sentiment Trading with News     True
# 30      1170894  Python Algo Stock Trading: Automate Your Trading!     True
# 41      1035472  Python for Finance: Investment Fundamentals & ...     True
# 147     1070886         Python Algo Trading: FX Trading with Oanda     True
# 334      815482               Stock Technical Analysis with Python     True
# 536      529828                     Python for Trading & Investing     True
# 762     1088656          Quantitative Trading Analysis with Python     True
# 863      902888          Investment Portfolio Analysis with Python     True
# 1682     546848  Learn to code in Python and learn Adobe Photos...     True
# 2497      16646                        Web Programming with Python     True
# 2528     391546        Learn Python and Django: Payment Processing     True
# ...

# %%
len(data[data['course_title'].str.contains('python', case=False)])
# Out:
# 29

# %%
#It means there are total 29 courses related to Python on udemy Platform.

# %% [markdown]
# # 11. Display 10 Most Popular Python Courses As Per Number Of Subscribers and and also plot Them On Barplot.

# %%
top10=data[data['course_title'].str.contains('python', case=False)]. \
sort_values(by="num_subscribers",ascending=False).head(10)
top10
# Out:
#       course_id                                       course_title  is_paid  \
# 2497      16646                        Web Programming with Python     True
# 2570      47963  Coding for Entrepreneurs: Learn Python, Django...     True
# 2528     391546        Learn Python and Django: Payment Processing     True
# 3200     822444  Python and Django Full Stack Web Developer Boo...     True
# 3507     394832  Fun and creative web engineering with Python a...    False
# 2553     938560  The Complete Ethical Hacking Course 2.0: Pytho...     True
# 3138     631128  Complete Python Web Course: Build 8 Python Web...     True
# 3197      76052  Try Django 1.9 | Build a Blog and Learn Python...     True
# 2681     477702  Python for Beginners: Python Programming Langu...     True
# 3203     970600                    REST APIs with Flask and Python     True
#
#       price  num_subscribers  num_reviews  num_lectures               level  \
# ...

# %%
sns.barplot(x="num_subscribers",y="course_title",data=top10)
plt.xlabel("Number of Subscriber",fontsize=15)
plt.ylabel("Course Title",fontsize=15)
plt.title("Top 10 python Courses based On Subscribers")
plt.show()

# %%
# Web Programming with python Course Have the Most subscribers of more than 30K while Rest apIs with flask With Python have subscribers of less than 7k.

# %% [markdown]
# # 12. In Which Year The Highest Number Of Courses Were Posted?

# %% [markdown]
# # a. Make a new column or Separate column that Showing only year and Convert To Numeric Datatype

# %%
data['Year']=data['published_timestamp'].dt.year

# %%
data.head(2)
# Out:
#    course_id                                       course_title  is_paid  \
# 0    1070968                 Ultimate Investment Banking Course     True
# 1    1113822  Complete GST Course & Certification - Grow You...     True
#
#    price  num_subscribers  num_reviews  num_lectures       level  \
# 0    200             2147           23            51  All Levels
# 1     75             2792          923           274  All Levels
#
#    content_duration       published_timestamp           subject  Year
# 0               1.5 2017-01-18 20:58:58+00:00  Business Finance  2017
# 1              39.0 2017-03-09 16:34:20+00:00  Business Finance  2017

# %% [markdown]
# # b. Find a count Of Courses Based on Year and Visualize Them.

# %%
data['Year'].value_counts()
# Out:
# 2016    1204
# 2015    1014
# 2017     713
# 2014     490
# 2013     201
# 2012      45
# 2011       5
# Name: Year, dtype: int64

# %%
sns.countplot('Year',data=data)
plt.xlabel("Year",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.title("Count Based On Year")
plt.show()

# %% [markdown]
# # 13. Display category-wise Count of Posted subjects[Year Wise]

# %%
data.groupby(['Year'])["subject"].value_counts()
# Out:
# Year  subject
# 2011  Web Development          5
# 2012  Web Development         19
#       Graphic Design          10
#       Musical Instruments     10
#       Business Finance         6
# 2013  Business Finance        84
#       Web Development         55
#       Musical Instruments     39
#       Graphic Design          23
# 2014  Business Finance       192
#       Musical Instruments    120
#       Web Development        113
#       Graphic Design          65
# 2015  Business Finance       339
#       Web Development        336
#       Musical Instruments    171
#       Graphic Design         168
# 2016  Web Development        448
#       Business Finance       347
#       Musical Instruments    228
#       Graphic Design         181
# 2017  Business Finance       223
#       Web Development        223
#       Graphic Design         155
#       Musical Instruments    112
# Name: subject, dtype: int64

# %%
sns.countplot(data=data, x="Year",hue="subject")
plt.xlabel("Year",fontsize=15)
plt.ylabel("Count",fontsize=15)
plt.legend(loc=2,shadow=True)
plt.title("Subjects Count Based On Year")
plt.show()

# %% [markdown]
# # a. How do you Explain the above pattern?

# %% [raw]
# **By see The Graph we can see that People chooses More Courses of Web Development and Business Finance irrespective of the Year.So we have to make a more  Content in upcoming Years based on This Records.

# %% [markdown]
# # 14. Find the Most Popular Course title On Udemy based On Number Of Subscribers?

# %%
data.columns
# Out:
# Index(['course_id', 'course_title', 'is_paid', 'price', 'num_subscribers',
#        'num_reviews', 'num_lectures', 'level', 'content_duration',
#        'published_timestamp', 'subject', 'Year'],
#       dtype='object')

# %%
data[data['num_subscribers'].max()==data['num_subscribers']]
# Out:
#       course_id                          course_title  is_paid  price  \
# 2827      41295  Learn HTML5 Programming From Scratch    False      0
#
#       num_subscribers  num_reviews  num_lectures       level  \
# 2827           268923         8629            45  All Levels
#
#       content_duration       published_timestamp          subject  Year
# 2827              10.5 2013-02-14 07:03:41+00:00  Web Development  2013

# %% [raw]
# ** From this table we can analyse that HTML5 Programming have the maximum number of subscribers of more than 25K than any other Courses
